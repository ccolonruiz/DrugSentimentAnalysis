# %%
import pandas as pd
import numpy as np

import Utils.bilinear_sim as sim
import Utils.data_utils as data
import keras.backend as K
from nltk.stem.snowball import SnowballStemmer
# Out:
# Using TensorFlow backend.

# %%
path_train = 'dataset/Raw/Train.csv'
path_test = 'dataset/Raw/Test.csv'

# %% [markdown]
# ## Dataset with StopWords

# %%
dataset = data.Dataset()
#dataset.load_pickle(path_train, path_test, label_name='rating')
dataset.load_csv(path_train, path_test, label_name='rating', separator='\t')
dataset.make_dev_split(dev_split=0.15)

# %%
dataset.parse_to_word_list(parse_col_name='review', alphanum_sep=True, blind_num=True)

# %%
dataset.classes_distribution()

# %%
dataset.classes_distribution('usefulCount >= 30')
# Out:
# 0.31187605492344106

# %%
dataset.text_len_distribution(col_name='review', plot=True)
# Out:
# max len of texts: 2006
# min len of texts: 0

# %% [markdown]
# ## Dataset without StopWords

# %%
dataset_non_stop = data.Dataset()
dataset_non_stop.load_csv(path_train, path_test, label_name='rating', separator='\t')
# dataset_non_stop.make_dev_split(dev_split=0.15)

# %%
dataset_non_stop.parse_to_word_list(parse_col_name='review', stop=True, alphanum_sep=True, blind_num=True)

# %%
dataset_non_stop.text_len_distribution(col_name='review', plot=True)
# Out:
# max len of texts: 1003
# min len of texts: 0
